# %% [markdown]
# # Modules

# %%
import pandas as pd

# %% [markdown]
# # Variables

# %%
dir_VFE = '01.Data/Vertical flight efficiency/Vertical_Flight_Efficiency_cdo_cco.xlsx'

# %% [markdown]
# # Load data

# %%
df_VFE = pd.read_excel(dir_VFE, engine='openpyxl', sheet_name='DATA')

# %%
df_VFE.head()
# Out:
#    YEAR  MONTH_NUM MONTH_MON APT_ICAO          APT_NAME STATE_NAME  \
# 0  2015          1       JAN     EBAW  Antwerpen Deurne    Belgium
# 1  2015          1       JAN     EBBE       Beauvechain    Belgium
# 2  2015          1       JAN     EBBL     Kleine Brogel    Belgium
# 3  2015          1       JAN     EBBR          Brussels    Belgium
# 4  2015          1       JAN     EBCI         Charleroi    Belgium
#
#    NBR_FLIGHTS_DESCENT  TOT_DIST_LEVEL_NM_DESCENT  \
# 0                  343                4148.460184
# 1                    7                 169.688987
# 2                    7                  54.574931
# 3                 8207              150501.189129
# 4                 1684               34298.796333
#
#    TOT_DIST_LEVEL_NM_DESCENT_BELOW_7000  TOT_TIME_LEVEL_SECONDS_DESCENT  ...  \
# 0                           2223.595073                           73600  ...
# 1                            169.688987                            4780  ...
# 2                             20.047403                             580  ...
# 3                          24019.820435                         1705480  ...
# 4                           4193.082197                          379940  ...
#
#    TOT_DIST_LEVEL_NM_CLIMB  TOT_DIST_LEVEL_NM_CLIMB_BELOW_10000  \
# 0              1001.292582                           261.146196
# 1                37.022418                            37.022418
# 2                45.650893                             0.000000
# 3             30402.684644                           532.468365
# 4             10355.749480                           636.848862
#
#    TOT_TIME_LEVEL_SECONDS_CLIMB  TOT_TIME_LEVEL_SECONDS_CLIMB_BELOW_10000  \
# 0                       16327.0                                    7707.0
# 1                        1140.0                                    1140.0
# 2                         440.0                                       0.0
# 3                      254281.0                                    7240.0
# 4                       91653.0                                   10808.0
#
#    MEDIAN_CCO_ALT  NBR_CCO_FLIGHTS  NBR_CCO_FLIGHTS_BELOW_10000  \
# 0    17000.000000            262.0                        308.0
# 1     6000.000000              5.0                          5.0
# 2    24038.333333              4.0                          6.0
# 3    34000.000000           6213.0                       8080.0
# 4    37000.000000           1093.0                       1553.0
#
#    TOT_DELTA_CO2_KG_CLIMB  TOT_DELTA_CO2_KG_CLIMB_BELOW_10000  \
# 0              559.502401                          130.283198
# 1                0.000000                            0.000000
# 2                0.000000                            0.000000
# 3            56477.198959                         3380.171219
# 4            16666.046934                         5045.674466
#
#            Airport Name
# 0        Antwerp (EBAW)
# 1    Beauvechain (EBBE)
# 2  Kleine Brogel (EBBL)
# 3       Brussels (EBBR)
# 4      Charleroi (EBCI)
#
# [5 rows x 27 columns]
