# %% [markdown]
# # 1.Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pandasql import sqldf

# %% [markdown]
# # 2.Variables

# %% [markdown]
# ## 2.1. Filenames

# %%
# National emissions reported to the Convention on Long-range Transboundary Air Pollution (LRTAP Convention), 2023
# https://sdi.eea.europa.eu/catalogue/srv/eng/catalog.search#/metadata/2999364f-be52-4012-b4fd-f98e2cc8fab6
ds_LRTAPemissions='01.Data/eea_t_lrtap-convention_p_1990-2021_v01_r00/CLRTAP_NVFR19_V23_1_GF_csv.csv'

# %% [markdown]
# ## 2.2. Analysis parameters

# %%
# European 27 Countries
countryEU27 = ['BE','BG','CZ','DK','DE','EE','IE','GR','ES','FR','HR','IT','CY','LV','LT','LU','HU','MT','NL','AT','PL','PT','RO','SI','SK','FI','SE']

# %% [markdown]
# # 3.Load data

# %%
df_LRTAPemissions=pd.read_csv(ds_LRTAPemissions,header=0,delimiter="\t", dtype='unicode')

# %% [markdown]
# # 4. Exploratory data analysis (EDA)

# %% [markdown]
# ## 4.1. EDA general

# %% [markdown]
# ### 4.1.1. Data preview (head)

# %%
df_LRTAPemissions.head()
# Out:
#   Country_Code  Country Pollutant_name Format_name Sector_code  Year  \
# 0           AT  Austria             As  NFR 2014-1        1A1a  1990
# 1           AT  Austria             As  NFR 2014-1        1A1b  1990
# 2           AT  Austria             As  NFR 2014-1        1A1c  1990
# 3           AT  Austria             As  NFR 2014-1        1A2a  1990
# 4           AT  Austria             As  NFR 2014-1        1A2b  1990
#
#   Emissions Unit Notation VersionId Parent_sector_code  \
# 0       NaN   Mg      NaN         1     NATIONAL TOTAL
# 1       NaN   Mg      NaN         1     NATIONAL TOTAL
# 2       NaN   Mg      NaN         1     NATIONAL TOTAL
# 3       NaN   Mg      NaN         1     NATIONAL TOTAL
# 4       NaN   Mg      NaN         1     NATIONAL TOTAL
#
#                                          Sector_name
# 0             Public electricity and heat production
# 1                                 Petroleum refining
# 2  Manufacture of solid fuels and other energy in...
# 3  Stationary combustion in manufacturing industr...
# 4  Stationary combustion in manufacturing industr...

# %% [markdown]
# ### 4.1.2. Data preview (tail)

# %%
df_LRTAPemissions.tail()
# Out:
#         Country_Code Country Pollutant_name                      Format_name  \
# 3933691        EEA32   EEA32            PCB  NEC NFR-1 sector classification
# 3933692        EEA32   EEA32      total PAH  NEC NFR-1 sector classification
# 3933693        EEA32   EEA32             Zn  NEC NFR-1 sector classification
# 3933694        EEA32   EEA32            HCB  NEC NFR-1 sector classification
# 3933695        EEA32   EEA32             Hg  NEC NFR-1 sector classification
#
#         Sector_code  Year              Emissions Unit Notation VersionId  \
# 3933691          5E  2009      80.94100949939022   kg      NaN       NaN
# 3933692       5C1bv  2011  0.0009683435030517829   Mg      NaN       NaN
# 3933693        3B4a  2009                      0   Mg      NaN       NaN
# 3933694        1A2f  2002     1.0821639623803498   kg      NaN       NaN
# 3933695        2A5a  2010                 0.0002   Mg      NaN       NaN
#
#         Parent_sector_code Sector_name
# 3933691                NaN         NaN
# 3933692                NaN         NaN
# 3933693                NaN         NaN
# 3933694                NaN         NaN
# 3933695                NaN         NaN

# %% [markdown]
# ### 4.1.3. Shape of dataset

# %%
df_LRTAPemissions.shape
# Out:
# (3933696, 12)

# %% [markdown]
# ### 4.1.4. Data types

# %%
df_LRTAPemissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933696 entries, 0 to 3933695
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Country_Code        object
#  1   Country             object
#  2   Pollutant_name      object
#  3   Format_name         object
#  4   Sector_code         object
#  5   Year                object
#  6   Emissions           object
#  7   Unit                object
#  8   Notation            object
#  9   VersionId           object
#  10  Parent_sector_code  object
#  11  Sector_name         object
# dtypes: object(12)
# memory usage: 360.1+ MB

# %% [markdown]
# ### 4.1.5. Data conversions

# %% [markdown]
# We can see that the columns `Year` and `Emissions` has `object` data type, let's correct them.

# %%
df_LRTAPemissions['Emissions'] = df_LRTAPemissions['Emissions'].astype("float")
df_LRTAPemissions['Year'] = df_LRTAPemissions['Year'].astype("int")

# %%
df_LRTAPemissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933696 entries, 0 to 3933695
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Country_Code        object
#  1   Country             object
#  2   Pollutant_name      object
#  3   Format_name         object
#  4   Sector_code         object
#  5   Year                int64
#  6   Emissions           float64
#  7   Unit                object
#  8   Notation            object
#  9   VersionId           object
#  10  Parent_sector_code  object
#  11  Sector_name         object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 360.1+ MB

# %% [markdown]
# ## 4.2. EDA dimensions

# %% [markdown]
# ### 4.2.1. Year

# %%
# Describe used with lambda functions to prevent exponential notation
df_LRTAPemissions['Year'].describe().apply(lambda x: format(x, 'f'))
# Out:
# count    3933696.000000
# mean        2005.500000
# std            9.233094
# min         1990.000000
# 25%         1997.750000
# 50%         2005.500000
# 75%         2013.250000
# max         2021.000000
# Name: Year, dtype: object

# %%
df_LRTAPemissions.Year.unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
df_LRTAPemissions.Year.nunique()
# Out:
# 32

# %% [markdown]
# ### 4.2.2. Country_code

# %%
df_LRTAPemissions.Country_Code.unique()
# Out:
# array(['AT', 'BE', 'DK', 'FI', 'FR', 'DE', 'GR', 'IE', 'IT', 'LU', 'NL',
#        'PT', 'ES', 'SE', 'BG', 'HR', 'CY', 'CZ', 'EE', 'HU', 'LT', 'LV',
#        'MT', 'PL', 'RO', 'SI', 'SK', 'EU27', 'CH', 'IS', 'LI', 'NO', 'TR',
#        'EEA32'], dtype=object)

# %%
df_LRTAPemissions.Country_Code.nunique()
# Out:
# 34

# %% [markdown]
# ### 4.2.3. Country

# %%
df_LRTAPemissions.Country.unique()
# Out:
# array(['Austria', 'Belgium', 'Denmark', 'Finland', 'France', 'Germany',
#        'Greece', 'Ireland', 'Italy', 'Luxembourg', 'Netherlands',
#        'Portugal', 'Spain', 'Sweden', 'Bulgaria', 'Croatia', 'Cyprus',
#        'Czechia', 'Estonia', 'Hungary', 'Lithuania', 'Latvia', 'Malta',
#        'Poland', 'Romania', 'Slovenia', 'Slovakia', 'EU27', 'Switzerland',
#        'Iceland', 'Liechtenstein', 'Norway', 'Türkiye', 'Czech Republic',
#        'EEA32'], dtype=object)

# %%
df_LRTAPemissions.Country.nunique()
# Out:
# 35

# %%
q = """SELECT Country_Code, COUNT(DISTINCT Country) FROM df_LRTAPemissions GROUP BY Country_Code HAVING COUNT(DISTINCT Country)>1;"""
pysqldf = lambda q: sqldf(q, globals())
df_duplicateCC = pysqldf(q)

# %%
df_duplicateCC
# Out:
#   Country_Code  COUNT(DISTINCT Country)
# 0           CZ                        2

# %%
q = """SELECT DISTINCT Country_Code, Country FROM df_LRTAPemissions WHERE Country_Code='CZ';"""
pysqldf = lambda q: sqldf(q, globals())
df_uniqueCC = pysqldf(q)

# %%
df_uniqueCC
# Out:
#   Country_Code         Country
# 0           CZ         Czechia
# 1           CZ  Czech Republic

# %% [markdown]
# ### 4.2.4. Pollutant name

# %%
df_LRTAPemissions.Pollutant_name.unique()
# Out:
# array(['As', 'BC', 'benzo(a)', 'benzo(b)', 'benzo(k)', 'Cd', 'CO', 'Cr',
#        'Cu', 'dioxin', 'HCB', 'Hg', 'Indeno', 'NH3', 'Ni', 'NMVOC', 'NOx',
#        'Pb', 'PCB', 'PM10', 'PM2.5', 'Se', 'SOx', 'total PAH', 'TSP',
#        'Zn'], dtype=object)

# %%
df_LRTAPemissions.Pollutant_name.nunique()
# Out:
# 26

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.countplot(x='Pollutant_name', data=df_LRTAPemissions);

# %% [markdown]
# ### 4.2.5. Version

# %%
df_LRTAPemissions.VersionId.unique()
# Out:
# array(['1', nan], dtype=object)

# %%
df_LRTAPemissions.VersionId.nunique()
# Out:
# 1

# %% [markdown]
# ### 4.2.6. Unit

# %%
q = """SELECT Pollutant_name, COUNT(DISTINCT Unit) FROM df_LRTAPemissions GROUP BY Pollutant_name HAVING COUNT(DISTINCT Unit)>1;"""
pysqldf = lambda q: sqldf(q, globals())
df_duplicateUNIT = pysqldf(q)

# %%
df_duplicateUNIT
# Out:
# Empty DataFrame
# Columns: [Pollutant_name, COUNT(DISTINCT Unit)]
# Index: []

# %% [markdown]
# There are not any `Pollutant_name` which is listed with more than one `Unit`.

# %% [markdown]
# ### 4.2.7. Notation

# %%
df_LRTAPemissions.Notation.unique()
# Out:
# array([nan], dtype=object)

# %%
df_LRTAPemissions.Notation.nunique()
# Out:
# 0

# %% [markdown]
# ## 4.3. EDA measures

# %% [markdown]
# ### 4.3.1. Emissions

# %%
# Describe used with lambda functions to prevent exponential notation
df_LRTAPemissions['Emissions'].describe().apply(lambda x: format(x, 'f'))
# Out:
# count    2419559.000000
# mean           9.293554
# std          257.592859
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.031999
# max        60480.189090
# Name: Emissions, dtype: object

# %% [markdown]
# # 5. Perimeter of analysis

# %% [markdown]
# ## 5.1. Sectors of interest

# %% [markdown]
# Let's filter only emissions from domestic and international aviation.

# %%
# List sectors of interest which include 'aviation' in their name
col=df_LRTAPemissions.Sector_name.unique()
for i in col: 
    if type(i) is str:
        if 'aviation' in i:
            print(i)
# Out:
# International aviation LTO (civil)
# Domestic aviation LTO (civil)
# International aviation cruise (civil)
# Domestic aviation cruise (civil)

# %%
# Define the sectors of interest
sectors_of_interest = [
    'International aviation LTO (civil)',
    'Domestic aviation LTO (civil)',
    'International aviation cruise (civil)',
    'Domestic aviation cruise (civil)'
]

# Filter the DataFrame for these sectors
df_emissions = df_LRTAPemissions[df_LRTAPemissions['Sector_name'].isin(sectors_of_interest)]

# %%
df_emissions.Sector_name.unique()
# Out:
# array(['International aviation LTO (civil)',
#        'Domestic aviation LTO (civil)',
#        'International aviation cruise (civil)',
#        'Domestic aviation cruise (civil)'], dtype=object)

# %% [markdown]
# ## 5.2. Country code

# %%
# Filter the DataFrame for these sectors
df_emissions = df_emissions[(df_emissions.Country_Code == 'EU27')]

# %%
df_emissions.Country_Code.unique()
# Out:
# array(['EU27'], dtype=object)

# %%
df_emissions.Country_Code.nunique()
# Out:
# 1

# %% [markdown]
# # 6. Management of Nan values

# %% [markdown]
# ## 6.1. Analysis of Nan values

# %% [markdown]
# ### 6.1.1. Nan values by Pollutant name

# %%
df_Nan_Pollutant = df_emissions.groupby(['Pollutant_name']).agg({'Emissions': lambda x: x.isnull().sum()})
df_Nan_Pollutant
# Out:
#                 Emissions
# Pollutant_name
# As                      0
# BC                      0
# CO                      0
# Cd                      0
# Cr                      0
# Cu                      0
# HCB                   128
# Hg                      0
# Indeno                  0
# NH3                     0
# NMVOC                   0
# NOx                     0
# Ni                      0
# PCB                    69
# PM10                    0
# PM2.5                   0
# Pb                      0
# SOx                     0
# Se                      0
# TSP                     0
# Zn                      0
# benzo(a)                0
# benzo(b)                0
# benzo(k)                0
# dioxin                  0
# total PAH               0

# %%
df_Nan_Pollutant['Emissions'].sum()
# Out:
# 197

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.barplot(x='Pollutant_name', y='Emissions', data=df_Nan_Pollutant, color='darkgray');

# %% [markdown]
# ### 6.1.2. Handle of rows with Nan emissions of `HCB`

# %% [markdown]
# As we don't have any information regarding the emissions of HCB from any year and any sector, we can't apply any strategy fo till the Nan values, just get rid of these rows.

# %%
df_emissions = df_emissions[~(df_emissions.Pollutant_name == 'HCB')]

# %% [markdown]
# ### 6.1.3. Handle of rows with Nan emissions of `PCB`

# %%
df_emissionsPCB = df_emissions[(df_emissions.Pollutant_name == 'PCB')]

# %%
df_emissionsPCB.groupby(['Sector_name']).size()
# Out:
# Sector_name
# Domestic aviation LTO (civil)            32
# Domestic aviation cruise (civil)         32
# International aviation LTO (civil)       32
# International aviation cruise (civil)    32
# dtype: int64

# %%
df_emissionsPCB.groupby(['Sector_name']).agg({'Emissions': lambda x: x.isnull().sum()})
# Out:
#                                        Emissions
# Sector_name
# Domestic aviation LTO (civil)                  0
# Domestic aviation cruise (civil)              32
# International aviation LTO (civil)             5
# International aviation cruise (civil)         32

# %% [markdown]
# For `Domestic aviation cruise (civil)` and `International aviation cruise (civil)	` we don't have any information so we can't fill the rows with Nan values, we proceed with the analysis of only `nternational aviation LTO (civil)	` rows.

# %%
df_emissionsPCB_LTO = df_emissionsPCB[(df_emissionsPCB.Sector_name == 'International aviation LTO (civil)')]

# %%
df_emissionsPCB_LTO.tail()
# Out:
#         Country_Code Country Pollutant_name Format_name Sector_code  Year  \
# 2750960         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2017
# 2754852         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2018
# 2758744         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2019
# 2762636         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2020
# 2766528         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2021
#
#          Emissions Unit Notation VersionId Parent_sector_code  \
# 2750960        NaN   kg      NaN         1     NATIONAL TOTAL
# 2754852        NaN   kg      NaN         1     NATIONAL TOTAL
# 2758744        NaN   kg      NaN         1     NATIONAL TOTAL
# 2762636        NaN   kg      NaN         1     NATIONAL TOTAL
# 2766528        NaN   kg      NaN         1     NATIONAL TOTAL
#
#                                 Sector_name
# 2750960  International aviation LTO (civil)
# 2754852  International aviation LTO (civil)
# 2758744  International aviation LTO (civil)
# 2762636  International aviation LTO (civil)
# 2766528  International aviation LTO (civil)

# %%
df_emissionsPCB_LTO = df_emissionsPCB_LTO.ffill()

# %%
df_emissionsPCB_LTO.tail()
# Out:
#         Country_Code Country Pollutant_name Format_name Sector_code  Year  \
# 2750960         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2017
# 2754852         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2018
# 2758744         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2019
# 2762636         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2020
# 2766528         EU27    EU27            PCB  NFR 2014-1    1A3ai(i)  2021
#
#             Emissions Unit  Notation VersionId Parent_sector_code  \
# 2750960  1.343840e-09   kg       NaN         1     NATIONAL TOTAL
# 2754852  1.343840e-09   kg       NaN         1     NATIONAL TOTAL
# 2758744  1.343840e-09   kg       NaN         1     NATIONAL TOTAL
# 2762636  1.343840e-09   kg       NaN         1     NATIONAL TOTAL
# 2766528  1.343840e-09   kg       NaN         1     NATIONAL TOTAL
#
#                                 Sector_name
# 2750960  International aviation LTO (civil)
# 2754852  International aviation LTO (civil)
# 2758744  International aviation LTO (civil)
# 2762636  International aviation LTO (civil)
# 2766528  International aviation LTO (civil)

# %%
# Delete rows from Pollutant_name == 'PCB' AND Sector_name == 'International aviation LTO (civil)'
df_emissions = df_emissions[~((df_emissions.Pollutant_name == 'PCB') & (df_emissionsPCB.Sector_name == 'International aviation LTO (civil)'))]

# %%
# Add df_emissionsPCB_LTO to df_emissions
df_emissions = pd.concat([df_emissions, df_emissionsPCB_LTO], axis=0)

# %%
df_emissionsPCB = df_emissions[(df_emissions.Pollutant_name == 'PCB')]
df_emissionsPCB.groupby(['Sector_name']).agg({'Emissions': lambda x: x.isnull().sum()})
# Out:
#                                        Emissions
# Sector_name
# Domestic aviation LTO (civil)                  0
# Domestic aviation cruise (civil)              32
# International aviation LTO (civil)             0
# International aviation cruise (civil)         32

# %% [markdown]
# # 7. Aggregation

# %% [markdown]
# ## 7.1. Pivot of data

# %%
def transform_df(df):
    # Group by Year and Pollutant_name, then sum the Emissions
    grouped = df.groupby(['Year', 'Pollutant_name'])['Emissions'].sum()

    # Pivot the table
    pivoted_df = grouped.unstack(level='Pollutant_name')

    # Reset index to make 'Year' a column
    pivoted_df.reset_index(inplace=True)

    return pivoted_df

# %%
# Use the function on your DataFrame
df_emissionsPV = transform_df(df_emissions)

# %%
df_emissionsPV
# Out:
# Pollutant_name  Year        As        BC          CO        Cd        Cr  \
# 0               1990  0.001071  2.298696  514.841454  0.003707  0.044906
# 1               1991  0.000896  2.193775  453.177145  0.003175  0.044566
# 2               1992  0.000853  2.215153  518.329998  0.003330  0.048017
# 3               1993  0.001054  2.199278  620.187543  0.003154  0.049412
# 4               1994  0.001050  2.223296  535.043975  0.003470  0.052866
# 5               1995  0.001060  2.279197  524.703774  0.003735  0.056727
# 6               1996  0.001044  2.317858  404.053229  0.003526  0.058998
# 7               1997  0.001154  2.367841  355.110231  0.003874  0.063733
# 8               1998  0.001214  2.448678  330.273810  0.004326  0.068062
# 9               1999  0.001362  2.553969  305.733224  0.004466  0.073160
# 10              2000  0.001490  2.718150  282.562834  0.004804  0.078032
# 11              2001  0.001655  2.656044  336.966174  0.004993  0.080747
# 12              2002  0.001687  2.597670  339.022478  0.004749  0.079079
# 13              2003  0.001706  2.662243  382.808479  0.005532  0.084193
# 14              2004  0.001731  2.772464  367.293459  0.006302  0.091861
# 15              2005  0.001923  2.917342  401.876505  0.006626  0.096575
# 16              2006  0.002123  3.012696  412.690995  0.006906  0.101057
# 17              2007  0.002248  3.141899  438.053797  0.007397  0.107686
# 18              2008  0.002182  3.130586  447.434362  0.007442  0.107758
# 19              2009  0.001864  2.902913  391.317096  0.006816  0.098445
# 20              2010  0.001929  2.903764  405.406262  0.006778  0.101913
# 21              2011  0.001858  4.859933  419.229804  0.006798  0.105578
# 22              2012  0.001686  2.914426  386.133784  0.006449  0.100059
# 23              2013  0.001801  2.836719  364.475786  0.006276  0.099624
# 24              2014  0.001924  2.889520  376.917044  0.006413  0.103386
# 25              2015  0.002085  2.975933  396.300747  0.006603  0.108518
# 26              2016  0.002200  3.162520  460.140767  0.006992  0.117223
# 27              2017  0.002518  3.442813  490.893461  0.007487  0.126854
# 28              2018  2.002743  3.616436  482.081943  0.008141  2.136001
# 29              2019  4.002833  3.643827  446.416466  0.008385  4.140504
# 30              2020  6.001051  1.518946  281.277464  0.005021  6.064098
# 31              2021  8.001241  1.946755  333.121574  0.005239  8.077286
#
# Pollutant_name        Cu        Hg    Indeno       NH3  ...          Pb  \
# 0               0.137487  0.013896  0.016692  0.772263  ...  209.058106
# 1               0.136758  0.013338  0.008351  0.757485  ...  109.642519
# 2               0.146645  0.013321  0.008160  0.816351  ...   99.187053
# 3               0.164067  0.013583  0.010088  0.859435  ...   77.374328
# 4               0.174008  0.013986  0.012146  0.893203  ...   70.425151
# 5               0.186442  0.014675  0.012302  0.926264  ...   60.947579
# 6               0.201223  0.014830  0.013508  0.970630  ...   61.682609
# 7               0.216323  0.015933  0.013515  1.007361  ...   59.992619
# 8               0.225492  0.017052  0.014408  1.036446  ...   57.315598
# 9               0.241646  0.018656  0.014842  1.112070  ...   64.107013
# 10              0.250347  0.020035  0.014647  1.179269  ...   60.795433
# 11              0.256282  0.020881  0.014880  1.149570  ...   62.841268
# 12              0.258054  0.020563  0.014312  1.139929  ...   64.541687
# 13              0.269886  0.021953  0.014769  1.157606  ...   61.772069
# 14              0.284593  0.023654  0.016386  1.191173  ...   58.525736
# 15              0.295468  0.025033  0.017916  1.370623  ...   54.989887
# 16              0.307276  0.026664  0.018976  1.439947  ...   54.136908
# 17              0.320240  0.028489  0.020921  1.492644  ...   53.697839
# 18              0.318135  0.028635  0.022313  1.508178  ...   52.045216
# 19              0.291045  0.026216  0.021176  1.463389  ...   53.476190
# 20              0.299180  0.027750  0.021640  1.441793  ...   49.510261
# 21              0.314424  0.028228  0.022558  1.379962  ...   48.809996
# 22              0.309649  0.026505  0.021910  1.476756  ...   46.648674
# 23              0.314904  0.026633  0.021797  1.492885  ...   44.380105
# 24              0.327122  0.027854  0.022052  1.441987  ...   39.763415
# 25              0.340239  0.029558  0.022226  1.441437  ...   39.968045
# 26              0.360775  0.031828  0.023578  1.550625  ...   37.552526
# 27              0.379647  0.035526  0.025404  1.693848  ...   36.918683
# 28              2.394489  2.038309  0.027807  1.742412  ...   37.046898
# 29              4.398484  4.039988  0.028477  1.732446  ...   36.684340
# 30              6.198355  6.017510  0.009144  0.796670  ...   27.166706
# 31              8.230456  8.021525  0.011761  1.025787  ...   31.017328
#
# Pollutant_name        SOx        Se       TSP        Zn  benzo(a)  benzo(b)  \
# 0               16.553998  0.030697  4.572956  1.243983  0.014689  0.107589
# 1               16.188352  0.030934  4.497849  0.947406  0.003604  0.022360
# 2               17.317928  0.033444  4.586130  0.937106  0.002921  0.017951
# 3               17.960344  0.035330  4.637420  1.110626  0.005540  0.039312
# 4               18.577065  0.036410  4.796721  1.155347  0.008032  0.060295
# 5               19.382708  0.039685  5.005602  1.174641  0.007552  0.056679
# 6               20.681113  0.043178  5.195250  1.090056  0.008138  0.060498
# 7               21.543001  0.046150  5.379016  1.230081  0.007500  0.055069
# 8               22.640648  0.050111  5.639982  1.330810  0.008050  0.059410
# 9               24.430146  0.056667  5.968153  1.433448  0.007726  0.057018
# 10              25.468900  0.061857  6.403090  1.563419  0.006685  0.048725
# 11              25.233930  0.063220  6.273748  1.751053  0.006726  0.048838
# 12              24.525822  0.063838  6.091092  1.756597  0.006444  0.046425
# 13              25.105948  0.069783  6.175604  1.868251  0.006469  0.046148
# 14              26.284582  0.071894  6.499816  1.967150  0.007285  0.052771
# 15              27.895620  0.075844  7.011222  2.154904  0.008469  0.062470
# 16              29.437510  0.080458  7.257164  2.346078  0.008810  0.064731
# 17              30.826354  0.087293  7.540066  2.477926  0.009093  0.066915
# 18              31.392490  0.083332  7.533847  2.433004  0.010184  0.075530
# 19              28.990281  0.077262  6.925159  2.084777  0.009772  0.072375
# 20              29.380898  0.079626  7.003334  2.082247  0.009383  0.069259
# 21              29.775518  0.080756  7.127871  1.989855  0.009892  0.073286
# 22              29.443071  0.078104  7.030620  1.810543  0.010167  0.075803
# 23              29.268696  0.075811  6.825800  1.915674  0.011029  0.082864
# 24              29.822745  0.077511  6.917742  2.031603  0.010967  0.082763
# 25              30.763943  0.079710  7.180208  2.171654  0.010715  0.080457
# 26              32.285852  0.082964  7.655571  2.273456  0.011278  0.084931
# 27              34.333479  0.086385  8.223323  2.578969  0.013231  0.100190
# 28              36.342701  2.090358  8.682105  4.833303  0.016166  0.123171
# 29              37.336961  4.093353  8.831097  6.881712  0.017391  0.132812
# 30              15.690047  6.034325  3.671553  7.442406  0.005192  0.037824
# 31              19.077914  8.045930  4.608084  9.562980  0.005258  0.037915
#
# Pollutant_name  benzo(k)    dioxin  total PAH
# 0               0.012862  0.021469   0.152477
# 1               0.002975  0.012369   0.037938
# 2               0.002398  0.011752   0.032137
# 3               0.004756  0.014064   0.060423
# 4               0.007042  0.016279   0.088264
# 5               0.006616  0.015750   0.083961
# 6               0.007106  0.015548   0.090145
# 7               0.006517  0.015617   0.083558
# 8               0.007016  0.015752   0.089926
# 9               0.006745  0.014622   0.087512
# 10              0.005817  0.013803   0.077164
# 11              0.005854  0.013494   0.077598
# 12              0.005607  0.012879   0.074120
# 13              0.005620  0.014766   0.074466
# 14              0.006356  0.016358   0.084291
# 15              0.007413  0.018153   0.099601
# 16              0.007716  0.018588   0.103749
# 17              0.007971  0.018945   0.108778
# 18              0.008954  0.019643   0.120846
# 19              0.008599  0.018342   0.115726
# 20              0.008262  0.017974   0.112557
# 21              0.008716  0.019073   0.118288
# 22              0.008962  0.019292   0.120432
# 23              0.009741  0.019667   0.128910
# 24              0.009698  0.019617   0.129250
# 25              0.009468  0.019380   0.127384
# 26              0.009976  0.020196   0.135012
# 27              0.011725  0.021502   0.155897
# 28              0.014351  0.024241   0.185929
# 29              0.015445  0.025568   0.196272
# 30              0.004582  0.009726   0.057536
# 31              0.004635  0.010327   0.060596
#
# [32 rows x 26 columns]

# %% [markdown]
# ## 7.2. Calculating moving average

# %%
pollutants = []

# Iterate over column names
for column in df_emissionsPV:
    if column != 'Year':
        df_emissionsPV['rolling_'+column] = df_emissionsPV[column].rolling(5).mean()
        pollutants.append(column)

# %%
df_emissionsPV
# Out:
# Pollutant_name  Year        As        BC          CO        Cd        Cr  \
# 0               1990  0.001071  2.298696  514.841454  0.003707  0.044906
# 1               1991  0.000896  2.193775  453.177145  0.003175  0.044566
# 2               1992  0.000853  2.215153  518.329998  0.003330  0.048017
# 3               1993  0.001054  2.199278  620.187543  0.003154  0.049412
# 4               1994  0.001050  2.223296  535.043975  0.003470  0.052866
# 5               1995  0.001060  2.279197  524.703774  0.003735  0.056727
# 6               1996  0.001044  2.317858  404.053229  0.003526  0.058998
# 7               1997  0.001154  2.367841  355.110231  0.003874  0.063733
# 8               1998  0.001214  2.448678  330.273810  0.004326  0.068062
# 9               1999  0.001362  2.553969  305.733224  0.004466  0.073160
# 10              2000  0.001490  2.718150  282.562834  0.004804  0.078032
# 11              2001  0.001655  2.656044  336.966174  0.004993  0.080747
# 12              2002  0.001687  2.597670  339.022478  0.004749  0.079079
# 13              2003  0.001706  2.662243  382.808479  0.005532  0.084193
# 14              2004  0.001731  2.772464  367.293459  0.006302  0.091861
# 15              2005  0.001923  2.917342  401.876505  0.006626  0.096575
# 16              2006  0.002123  3.012696  412.690995  0.006906  0.101057
# 17              2007  0.002248  3.141899  438.053797  0.007397  0.107686
# 18              2008  0.002182  3.130586  447.434362  0.007442  0.107758
# 19              2009  0.001864  2.902913  391.317096  0.006816  0.098445
# 20              2010  0.001929  2.903764  405.406262  0.006778  0.101913
# 21              2011  0.001858  4.859933  419.229804  0.006798  0.105578
# 22              2012  0.001686  2.914426  386.133784  0.006449  0.100059
# 23              2013  0.001801  2.836719  364.475786  0.006276  0.099624
# 24              2014  0.001924  2.889520  376.917044  0.006413  0.103386
# 25              2015  0.002085  2.975933  396.300747  0.006603  0.108518
# 26              2016  0.002200  3.162520  460.140767  0.006992  0.117223
# 27              2017  0.002518  3.442813  490.893461  0.007487  0.126854
# 28              2018  2.002743  3.616436  482.081943  0.008141  2.136001
# 29              2019  4.002833  3.643827  446.416466  0.008385  4.140504
# 30              2020  6.001051  1.518946  281.277464  0.005021  6.064098
# 31              2021  8.001241  1.946755  333.121574  0.005239  8.077286
#
# Pollutant_name        Cu        Hg    Indeno       NH3  ...  rolling_Pb  \
# 0               0.137487  0.013896  0.016692  0.772263  ...         NaN
# 1               0.136758  0.013338  0.008351  0.757485  ...         NaN
# 2               0.146645  0.013321  0.008160  0.816351  ...         NaN
# 3               0.164067  0.013583  0.010088  0.859435  ...         NaN
# 4               0.174008  0.013986  0.012146  0.893203  ...  113.137431
# 5               0.186442  0.014675  0.012302  0.926264  ...   83.515326
# 6               0.201223  0.014830  0.013508  0.970630  ...   73.923344
# 7               0.216323  0.015933  0.013515  1.007361  ...   66.084457
# 8               0.225492  0.017052  0.014408  1.036446  ...   62.072711
# 9               0.241646  0.018656  0.014842  1.112070  ...   60.809083
# 10              0.250347  0.020035  0.014647  1.179269  ...   60.778654
# 11              0.256282  0.020881  0.014880  1.149570  ...   61.010386
# 12              0.258054  0.020563  0.014312  1.139929  ...   61.920200
# 13              0.269886  0.021953  0.014769  1.157606  ...   62.811494
# 14              0.284593  0.023654  0.016386  1.191173  ...   61.695239
# 15              0.295468  0.025033  0.017916  1.370623  ...   60.534129
# 16              0.307276  0.026664  0.018976  1.439947  ...   58.793257
# 17              0.320240  0.028489  0.020921  1.492644  ...   56.624488
# 18              0.318135  0.028635  0.022313  1.508178  ...   54.679117
# 19              0.291045  0.026216  0.021176  1.463389  ...   53.669208
# 20              0.299180  0.027750  0.021640  1.441793  ...   52.573283
# 21              0.314424  0.028228  0.022558  1.379962  ...   51.507900
# 22              0.309649  0.026505  0.021910  1.476756  ...   50.098067
# 23              0.314904  0.026633  0.021797  1.492885  ...   48.565045
# 24              0.327122  0.027854  0.022052  1.441987  ...   45.822490
# 25              0.340239  0.029558  0.022226  1.441437  ...   43.914047
# 26              0.360775  0.031828  0.023578  1.550625  ...   41.662553
# 27              0.379647  0.035526  0.025404  1.693848  ...   39.716555
# 28              2.394489  2.038309  0.027807  1.742412  ...   38.249913
# 29              4.398484  4.039988  0.028477  1.732446  ...   37.634098
# 30              6.198355  6.017510  0.009144  0.796670  ...   35.073831
# 31              8.230456  8.021525  0.011761  1.025787  ...   33.766791
#
# Pollutant_name  rolling_SOx  rolling_Se  rolling_TSP  rolling_Zn  \
# 0                       NaN         NaN          NaN         NaN
# 1                       NaN         NaN          NaN         NaN
# 2                       NaN         NaN          NaN         NaN
# 3                       NaN         NaN          NaN         NaN
# 4                 17.319537    0.033363     4.618215    1.078894
# 5                 17.885279    0.035161     4.704744    1.065026
# 6                 18.783832    0.037609     4.844225    1.093555
# 7                 19.628846    0.040150     5.002802    1.152150
# 8                 20.564907    0.043107     5.203314    1.196187
# 9                 21.735523    0.047158     5.437601    1.251807
# 10                22.952762    0.051592     5.717098    1.329563
# 11                23.863325    0.055601     5.932798    1.461762
# 12                24.459889    0.059139     6.075213    1.567065
# 13                24.952949    0.063073     6.182337    1.674554
# 14                25.323836    0.066118     6.288670    1.781294
# 15                25.809180    0.068916     6.410296    1.899591
# 16                26.649896    0.072363     6.606980    2.018596
# 17                27.910002    0.077054     6.896774    2.162862
# 18                29.167311    0.079764     7.168423    2.275812
# 19                29.708451    0.080838     7.253492    2.299338
# 20                30.005506    0.081594     7.251914    2.284807
# 21                30.073108    0.081654     7.226056    2.213562
# 22                29.796452    0.079816     7.124166    2.080085
# 23                29.371693    0.078312     6.982557    1.976620
# 24                29.538186    0.078362     6.981074    1.965985
# 25                29.814795    0.078378     7.016448    1.983866
# 26                30.316861    0.078820     7.121988    2.040586
# 27                31.294943    0.080476     7.360529    2.194271
# 28                32.709744    0.483386     7.731790    2.777797
# 29                34.212587    1.286554     8.114461    3.747819
# 30                31.197808    2.477477     7.412730    4.801969
# 31                28.556221    4.070070     6.803232    6.259874
#
# Pollutant_name  rolling_benzo(a)  rolling_benzo(b)  rolling_benzo(k)  \
# 0                            NaN               NaN               NaN
# 1                            NaN               NaN               NaN
# 2                            NaN               NaN               NaN
# 3                            NaN               NaN               NaN
# 4                       0.006957          0.049501          0.006007
# 5                       0.005530          0.039319          0.004758
# 6                       0.006436          0.046947          0.005584
# 7                       0.007352          0.054371          0.006407
# 8                       0.007854          0.058390          0.006859
# 9                       0.007793          0.057735          0.006800
# 10                      0.007620          0.056144          0.006640
# 11                      0.007337          0.053812          0.006390
# 12                      0.007126          0.052083          0.006208
# 13                      0.006810          0.049431          0.005929
# 14                      0.006722          0.048582          0.005851
# 15                      0.007079          0.051331          0.006170
# 16                      0.007495          0.054509          0.006543
# 17                      0.008025          0.058607          0.007015
# 18                      0.008768          0.064483          0.007682
# 19                      0.009266          0.068404          0.008131
# 20                      0.009449          0.069762          0.008301
# 21                      0.009665          0.071473          0.008500
# 22                      0.009880          0.073251          0.008699
# 23                      0.010049          0.074717          0.008856
# 24                      0.010288          0.076795          0.009076
# 25                      0.010554          0.079035          0.009317
# 26                      0.010831          0.081364          0.009569
# 27                      0.011444          0.086241          0.010122
# 28                      0.012472          0.094302          0.011044
# 29                      0.013756          0.104312          0.012193
# 30                      0.012652          0.095786          0.011216
# 31                      0.011448          0.086382          0.010148
#
# Pollutant_name  rolling_dioxin  rolling_total PAH
# 0                          NaN                NaN
# 1                          NaN                NaN
# 2                          NaN                NaN
# 3                          NaN                NaN
# 4                     0.015186           0.074248
# 5                     0.014043           0.060545
# 6                     0.014678           0.070986
# 7                     0.015451           0.081270
# 8                     0.015789           0.087171
# 9                     0.015458           0.087021
# 10                    0.015068           0.085661
# 11                    0.014658           0.083152
# 12                    0.014110           0.081264
# 13                    0.013913           0.078172
# 14                    0.014260           0.077528
# 15                    0.015130           0.082015
# 16                    0.016149           0.087245
# 17                    0.017362           0.094177
# 18                    0.018338           0.103453
# 19                    0.018734           0.109740
# 20                    0.018698           0.112331
# 21                    0.018795           0.115239
# 22                    0.018865           0.117570
# 23                    0.018870           0.119183
# 24                    0.019125           0.121888
# 25                    0.019406           0.124853
# 26                    0.019631           0.128198
# 27                    0.020073           0.135291
# 28                    0.020987           0.146695
# 29                    0.022177           0.160099
# 30                    0.020247           0.146129
# 31                    0.018273           0.131246
#
# [32 rows x 51 columns]

# %% [markdown]
# ## 7.3. Plotting

# %%
fig, ax = plt.subplots(figsize=(20,5))
plt.title('Cr') 
ax.set_facecolor('white')

color = 'tab:red'
ax.set_xlabel('Year')
ax.plot(df_emissionsPV['Year'], df_emissionsPV['Cr'],color) 

'''color = 'tab:blue'
ax1.plot(df_emissionsPV['Year'], df_emissionsPV['rolling_Cr'],color) '''

plt.grid()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(20,5))
plt.title('Cr') 

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.plot(df_emissionsPV['Year'], df_emissionsPV['Cr']) 


plt.grid()
plt.show()

# %%
for x in pollutants:
    fig, ax1 = plt.subplots(figsize=(20,5))
    plt.title(x) 

    color = 'tab:red'
    ax1.set_xlabel('Year')
    ax1.plot(df_emissionsPV['Year'], df_emissionsPV[x],color=color) 
    
    
    color = 'tab:blue'
    ax1.plot(df_emissionsPV['Year'], df_emissionsPV['rolling_'+x],color=color) 
    
    plt.grid()
    plt.show()

# %% [markdown]
# # 7.3. Correlation between year and emissions

# %% [markdown]
# # 8. Export
